# %% [markdown]
# # Semana 3 — Funciones, modularización, buenas prácticas y Git/GitHub
#
# **Tema:** Funciones, modularización básica, comprensión de listas y diccionarios, manejo de errores, buenas prácticas de programación e introducción a Git y GitHub.
#
# ## Propósito de la clase
#
# En esta clase se fortalecen los fundamentos de programación en Python necesarios para desarrollar análisis de datos ordenados, reutilizables y reproducibles. Además, se introduce el uso de Git y GitHub como herramientas para documentar y entregar trabajos del curso.
#
# ## Resultados esperados
#
# Al finalizar la clase, el estudiante estará en capacidad de:
#
# 1. Definir funciones con parámetros y valores de retorno.
# 2. Modularizar código básico para evitar repeticiones.
# 3. Usar comprensión de listas y diccionarios.
# 4. Manejar errores mediante `try`, `except`, `else` y `finally`.
# 5. Aplicar buenas prácticas de programación en notebooks.
# 6. Crear la estructura inicial de un repositorio para análisis de datos.
# 7. Comprender el flujo básico de trabajo con Git y GitHub.

# %% [markdown]
# ## 1. ¿Por qué usar funciones en análisis de datos?
#
# En análisis de datos, muchas tareas se repiten:
#
# - Calcular indicadores.
# - Validar rangos.
# - Limpiar valores.
# - Clasificar estados.
# - Generar resúmenes.
# - Transformar columnas.
# - Crear gráficas.
#
# Las funciones permiten organizar estas tareas y reutilizarlas.

# %%
# Ejemplo sin función: código repetido

temperatura_1 = 35
temperatura_2 = 44
temperatura_3 = 52

if temperatura_1 < 40:
    estado_1 = "Normal"
elif temperatura_1 < 50:
    estado_1 = "Precaución"
else:
    estado_1 = "Alerta"

if temperatura_2 < 40:
    estado_2 = "Normal"
elif temperatura_2 < 50:
    estado_2 = "Precaución"
else:
    estado_2 = "Alerta"

if temperatura_3 < 40:
    estado_3 = "Normal"
elif temperatura_3 < 50:
    estado_3 = "Precaución"
else:
    estado_3 = "Alerta"

print(estado_1, estado_2, estado_3)

# %% [markdown]
# El código anterior funciona, pero es repetitivo.
# La solución es crear una función.

# %%
def clf_temperatura(temperatura):
  if temperatura < 40:
      estado_1 = "Normal"
  elif temperatura < 50:
      estado_1 = "Precaución"
  else:
      estado_1 = "Alerta"
  return estado_1

print(clf_temperatura(35))
print(clf_temperatura(44))
print(clf_temperatura(52))
# Out:
# Normal
# Precaución
# Alerta

# %% [markdown]
# ## 2. Estructura de una función
#
# Una función puede tener:
#
# - Nombre.
# - Parámetros de entrada.
# - Instrucciones.
# - Valor de retorno.
#
# ```python
# def nombre_funcion(parametro_1, parametro_2):
#     resultado = parametro_1 + parametro_2
#     return resultado
# ```

# %%
print("Potencia:", potencia_motor, "W")

# %% [markdown]
# ## 3. Parámetros con valores por defecto
#
# Los parámetros con valores por defecto permiten que una función use un valor estándar cuando no se entrega un argumento.

# %%
def calcular_energia(voltaje, corriente, horas=1):
    energia = voltaje * corriente * horas
    return energia

print("Energía en 1 hora:", calcular_energia(12, 5))
print("Energía en 3 horas:", calcular_energia(12, 5, 3))
# Out:
# Energía en 1 hora: 60
# Energía en 3 horas: 180

# %% [markdown]
# ## 4. Funciones con validación básica
#
# Una buena función puede verificar que los datos de entrada sean válidos antes de hacer el cálculo.

# %%
def calcular_potencia_segura(voltaje, corriente):
  if voltaje < 0 or corriente < 0:
    return None
  return voltaje * corriente

print("Potencia:", calcular_potencia_segura(12, 5))
print("Potencia:", calcular_potencia_segura(-12, 5))
# Out:
# Potencia: 60
# Potencia: None

# %% [markdown]
# ## 5. Modularización básica
#
# Modularizar significa dividir un problema en partes pequeñas.
# Por ejemplo, para analizar mediciones de un motor, se pueden crear funciones para:
#
# 1. Calcular potencia.
# 2. Clasificar temperatura.
# 3. Clasificar corriente.
# 4. Generar un resumen.

# %%
def calcular_potencia(voltaje, corriente):
    return voltaje * corriente

def clasificar_temperatura(temp):
    if temp < 40:
        return "Normal"
    elif temp < 50:
        return "Precaución"
    else:
        return "Alerta"

def clasificar_corriente(corriente):
    if corriente < 2.0:
        return "Baja"
    elif corriente <= 3.0:
        return "Normal"
    else:
        return "Alta"

def generar_resumen(voltaje, corriente, temperatura):
    potencia = calcular_potencia(voltaje, corriente)
    estado_temp = clasificar_temperatura(temperatura)
    estado_corriente = clasificar_corriente(corriente)

    resumen = {
        "voltaje_V": voltaje,
        "corriente_A": corriente,
        "temperatura_C": temperatura,
        "potencia_W": potencia,
        "estado_temperatura": estado_temp,
        "estado_corriente": estado_corriente
    }

    return resumen

generar_resumen(12, 2.5, 43)

# %% [markdown]
# ## 6. Comprensión de listas
#
# La comprensión de listas permite crear listas de forma compacta.
#
# Sintaxis general:
#
# ```python
# nueva_lista = [expresion for elemento in lista]
# ```

# %% [markdown]
# ![Captura de Pantalla 2022-05-30 a la(s) 10.28.05 a.m..png](data:image/png;base64,...)

# %%
temperaturas = [35, 38, 41, 45, 52]

# Forma tradicional
temperaturas_f = []

for temp in temperaturas:
    temp_f = (temp * 9/5) + 32
    temperaturas_f.append(temp_f)

print(temperaturas_f)
# Out:
# [95.0, 100.4, 105.8, 113.0, 125.6]

# %%
# Con comprensión de listas
temperaturas_f = [(temp * 9/5) + 32 for temp in temperaturas]
print(temperaturas_f)
# Out:
# [95.0, 100.4, 105.8, 113.0, 125.6]

# %% [markdown]
# También se pueden incluir condiciones.

# %%
temperaturas_altas = [temp for temp in temperaturas if temp > 45]
print(temperaturas_altas)
# Out:
# [52]

# %%
estados = [clf_temperatura(temp) for temp in temperaturas]
print(estados)
# Out:
# ['Normal', 'Normal', 'Precaución', 'Precaución', 'Alerta']

# %% [markdown]
# ## 7. Comprensión de diccionarios
#
# La comprensión de diccionarios permite crear diccionarios de forma compacta.
#
# Sintaxis general:
#
# ```python
# nuevo_diccionario = {clave: valor for elemento in secuencia}
# ```

# %% [markdown]
# ![Captura de Pantalla 2022-05-30 a la(s) 11.09.10 a.m..png](data:image/png;base64,...)

# %%
temperaturas = [35, 38, 41, 45, 52]

diccionario_temperaturas = {
    f"muestra_{i+1}": temp
    for i, temp in enumerate(temperaturas)
}

diccionario_temperaturas
# Out:
# {'muestra_1': 35,
#  'muestra_2': 38,
#  'muestra_3': 41,
#  'muestra_4': 45,
#  'muestra_5': 52}

# %% [markdown]
# ## 8. Manejo de errores
#
# En análisis de datos pueden aparecer errores por:
#
# - Valores vacíos.
# - Tipos de datos incorrectos.
# - Divisiones por cero.
# - Archivos inexistentes.
# - Columnas mal nombradas.
# - Datos fuera de rango.
#
# Python permite manejar errores mediante `try` y `except`.

# %%
valor = "try"

try:
    numero = float(valor)
    print("Numero convertido:", numero)
    print(numero/190)
except:
    print("No se pudo convertir el numero")
# Out:
# No se pudo convertir el numero

# %% [markdown]
# ### Capturar errores específicos
#
# Es mejor capturar errores específicos en lugar de usar `except` general.

# %%
valor = "texto"

# %% [markdown]
# ### Uso de `else` y `finally`
#
# - `else`: se ejecuta si no ocurrió error.
# - `finally`: se ejecuta siempre.

# %%
valor = "15"

# %% [markdown]
# ## 9. Función robusta para conversión de datos
#
# Una función robusta puede manejar datos incorrectos sin detener todo el análisis.

# %%
def convertir_a_float(valor):
  try:
    return float(valor)
  except:
    return None

datos_crudos = ["34.5", "36.0", "", "error", "42.5", None, "51.0"]

datos_convertidos = [convertir_a_float(valor) for valor in datos_crudos]
datos_convertidos
# Out:
# [34.5, 36.0, None, None, 42.5, None, 51.0]

# %% [markdown]
# ## 10. Buenas prácticas de programación en notebooks
#
# Un notebook de análisis de datos debe ser comprensible y reproducible.
#
# Buenas prácticas:
#
# 1. Usar nombres claros para variables y funciones.
# 2. Separar el código por secciones.
# 3. Escribir explicaciones en celdas de texto.
# 4. Ejecutar las celdas en orden.
# 5. Evitar código repetido.
# 6. Crear funciones para tareas repetitivas.
# 7. No dejar errores sin resolver.
# 8. Documentar decisiones importantes.
# 9. Mantener los datos originales separados de los datos procesados.
# 10. Guardar el trabajo en un repositorio.

# %%
# Ejemplo de función documentada con docstring

def calcular_promedio(valores):
  """
  Calcula el promedio de una lista de valores numéricos.

  Args:
    valores (list): Lista de valores numéricos.

  Returns:
    float: Promedio de los valores.
  """
  if len(valores) == 0:
    return None

  return sum(valores)/len(valores)

calcular_promedio([10, 20, 30])
# Out:
# 20.0

# %% [markdown]
# ## 11. Introducción a Git y GitHub
#
# **Git** es un sistema de control de versiones.
# Permite registrar cambios en los archivos de un proyecto.
#
# **GitHub** es una plataforma para alojar repositorios en la nube.
# Permite guardar, compartir, documentar y entregar proyectos.
#
# En este curso, GitHub se usará para:
#
# - Entregar notebooks.
# - Documentar proyectos.
# - Registrar avances.
# - Compartir código.
# - Hacer seguimiento a la reproducibilidad.

# %% [markdown]
# ## 12. Estructura recomendada del repositorio inicial
#
# Para esta asignatura se recomienda crear un repositorio con esta estructura:
#
# ```text
# analisis-datos-python/
# │
# ├── README.md
# ├── requirements.txt
# ├── notebooks/
# │   ├── semana_02_introduccion.ipynb
# │   └── semana_03_fundamentos_python.ipynb
# │
# ├── data/
# │   ├── raw/
# │   └── processed/
# │
# ├── src/
# │   └── funciones.py
# │
# └── reports/
#     └── figuras/
# ```
#
# Descripción:
#
# - `README.md`: descripción del proyecto o curso.
# - `requirements.txt`: librerías necesarias.
# - `notebooks/`: notebooks del curso.
# - `data/raw/`: datos originales.
# - `data/processed/`: datos procesados.
# - `src/`: funciones reutilizables.
# - `reports/figuras/`: gráficas generadas.

# %% [markdown]
# ## 13. Comandos básicos de Git
#
# Estos comandos se ejecutan normalmente en la terminal del computador.
# En Google Colab también se pueden ejecutar anteponiendo `!`.
#
# ```bash
# git init
# git status
# git add .
# git commit -m "Primer commit"
# git branch -M main
# git remote add origin URL_DEL_REPOSITORIO
# git push -u origin main
# ```
#
# > Nota: para subir archivos desde Colab a GitHub puede ser necesario usar autenticación mediante token o hacer la carga manual desde la interfaz web de GitHub.

# %%
# En Colab se pueden ejecutar algunos comandos de terminal con !
# Esta celda es demostrativa.

# !git --version

# %% [markdown]
# ## 14. Crear carpetas desde Python
#
# También podemos crear una estructura de carpetas desde Python.

# %%
from pathlib import Path

estructura = [
    "notebooks",
    "data/raw",
    "data/processed",
    "src",
    "reports/figuras"
]

for carpeta in estructura:
    Path(carpeta).mkdir(parents=True, exist_ok=True)

print("Estructura de carpetas creada.")

# %% [markdown]
# ## 15. Crear un archivo README básico desde Python
#
# El archivo `README.md` debe explicar el propósito del repositorio.

# %%
contenido_readme = """# Análisis de Datos con Python

Repositorio inicial para la asignatura Análisis de Datos con Python.

## Contenido

- Notebooks de clase
- Talleres prácticos
- Datos originales
- Datos procesados
- Funciones reutilizables
- Resultados y gráficas

## Herramientas

- Python
- Google Colab
- Pandas
- NumPy
- Matplotlib
- Git y GitHub
"""

Path("README.md").write_text(contenido_readme, encoding="utf-8")

print("README.md creado.")

# %%
# !ls -R

# %% [markdown]
# ## 16. Mini caso de cierre
#
# Aplique funciones, comprensión de listas, manejo de errores y buenas prácticas a un pequeño conjunto de datos crudos.

# %%
datos_crudos = ["34.5", "36.0", "", "error", "42.5", None, "51.0"]

def convertir_a_float(valor):
    """
    Utiliza try-except para convierte datos de texto a flotante; datos vaciós y
    datos inválidos son ignorados.
    """
    try:
        return float(valor)
    except (ValueError, TypeError):
        return None

# %%
def clasificar_temperatura(temp):
    """
    Clasifica temperaturas según un umbral con condicionales.
    Si es None, devuelve "Dato inválido", si es menor a 40, devuelve "Normal",
    si es menor a 50, devuelve "Precaución", si es mayor o igual a 50, devuelve "Alerta".
    """
    if temp is None:
        return "Dato inválido"
    elif temp < 40:
        return "Normal"
    elif temp < 50:
        return "Precaución"
    else:
        return "Alerta"

# %%
# Utiliza compresión de listas para transforma la lista datos_crudos iterando elemento
  # por elemento, aplicando la función convertir_a_float a cada uno para obtener números
  # decimales y guardarlos en una nueva lista.
temperaturas_limpias = [convertir_a_float(valor) for valor in datos_crudos]

# %%
# Utiliza compresión de listas para tomar la lista de números ya convertidos
  # (temperaturas_limpias) y le aplica la función clasificar_temperatura a cada uno para
  # generar una nueva lista con sus respectivos estados o categorías.
estados = [clasificar_temperatura(temp) for temp in temperaturas_limpias]

# %%
resumen = {
    "datos_originales": datos_crudos,
    "datos_convertidos": temperaturas_limpias,
    "estados": estados
}

resumen
# Out:
# {'datos_originales': ['34.5', '36.0', '', 'error', '42.5', None, '51.0'],
#  'datos_convertidos': [34.5, 36.0, None, None, 42.5, None, 51.0],
#  'estados': ['Normal',
#   'Normal',
#   'Dato inválido',
#   'Dato inválido',
#   'Precaución',
#   'Dato inválido',
#   'Alerta']}

# %% [markdown]
# ## Preguntas de reflexión
#
# 1. ¿Qué ventaja tiene convertir una tarea repetitiva en una función?
# 2. ¿Qué diferencia hay entre comprensión de listas y un ciclo `for` tradicional?
# 3. ¿Por qué es importante manejar errores en análisis de datos?
# 4. ¿Qué debe contener el README de un repositorio?
# 5. ¿Por qué GitHub ayuda a la reproducibilidad?
