# %% [markdown]
# # Semana 2 — Fundamentos de Python para análisis de datos
#
# **Tema:** Variables, tipos de datos, operadores, estructuras de control, listas, tuplas, diccionarios y conjuntos
#
# ## Propósito de la clase
#
# En esta clase se estudian los fundamentos de Python necesarios para iniciar el trabajo con datos.
# Los ejemplos se presentan con situaciones cercanas a la ingeniería mecatrónica: mediciones, sensores, estados de operación, consumo energético y registro de datos.
#
# ## Resultados esperados
#
# Al finalizar la clase, el estudiante estará en capacidad de:
#
# 1. Crear variables y reconocer tipos de datos básicos.
# 2. Aplicar operadores aritméticos, relacionales y lógicos.
# 3. Usar estructuras condicionales para tomar decisiones.
# 4. Recorrer datos mediante ciclos `for` y `while`.
# 5. Manipular listas, tuplas, diccionarios y conjuntos.
# 6. Representar información básica de un sistema mecatrónico usando estructuras de datos de Python.

# %% [markdown]
# ## 1. Variables en Python
#
# Una variable es un nombre que permite almacenar un valor.
# En análisis de datos, las variables pueden representar mediciones, nombres, estados, fechas, resultados o parámetros de un sistema.

# %%
# Ejemplo: variables asociadas a una medición de un motor



print("Equipo:", nombre_equipo)
print("Voltaje:", voltaje_V, "V")
print("Corriente:", corriente_A, "A")
print("Temperatura:", temperatura_C, "°C")
print("¿Equipo activo?", equipo_activo)

# %% [markdown]
# ### Buenas prácticas para nombrar variables
#
# - Usar nombres claros y descriptivos.
# - Evitar espacios y caracteres especiales.
# - Usar minúsculas y guion bajo cuando sea necesario.
# - No usar palabras reservadas de Python como `if`, `for`, `while`, `list`, `dict`.
#
# Ejemplo recomendado: `temperatura_motor`
# Ejemplo no recomendado: `x1`, `temp motor`, `for`

# %%
# Ejemplo de nombres claros

# %% [markdown]
# ## 2. Tipos de datos básicos
#
# Python permite trabajar con diferentes tipos de datos.
#
# | Tipo | Nombre en Python | Ejemplo |
# |---|---|---|
# | Entero | `int` | `10` |
# | Decimal | `float` | `3.14` |
# | Texto | `str` | `"sensor"` |
# | Booleano | `bool` | `True`, `False` |
# | Nulo | `NoneType` | `None` |

# %%
              # int
             # float
           # str
             # bool
   # NoneType

print(type(muestras))
print(type(voltaje))
print(type(sensor))
print(type(alarma))
print(type(fecha_calibracion))

# %% [markdown]
# ### Conversión de tipos
#
# A veces es necesario convertir datos. Por ejemplo, un dato leído desde un archivo o desde un formulario puede llegar como texto y debe convertirse a número.

# %%
print(valor_texto, type(valor_texto))
print(valor_numerico, type(valor_numerico))

# %%
# Conversión a entero, flotante y texto


print(numero_entero, type(numero_entero))
print(numero_decimal, type(numero_decimal))
print(texto, type(texto))

# %% [markdown]
# ## 3. Operadores aritméticos
#
# Los operadores permiten realizar cálculos.
#
# | Operador | Significado |
# |---|---|
# | `+` | suma |
# | `-` | resta |
# | `*` | multiplicación |
# | `/` | división |
# | `//` | división entera |
# | `%` | módulo o residuo |
# | `**` | potencia |

# %%
print("Potencia:", potencia, "W")
print("Energía en 2 horas:", energia_2h, "Wh")

# %%
# Otros operadores aritméticos

a = 17
b = 5

print("Suma:", a + b)
print("Resta:", a - b)
print("Multiplicación:", a * b)
print("División:", a / b)
print("División entera:", a // b)
print("Residuo:", a % b)
print("Potencia:", a ** 2)

# %% [markdown]
# ## 4. Operadores relacionales y lógicos
#
# Los operadores relacionales comparan valores y devuelven `True` o `False`.
#
# | Operador | Significado |
# |---|---|
# | `==` | igual |
# | `!=` | diferente |
# | `>` | mayor que |
# | `<` | menor que |
# | `>=` | mayor o igual |
# | `<=` | menor o igual |
#
# Los operadores lógicos permiten combinar condiciones:
#
# | Operador | Significado |
# |---|---|
# | `and` | ambas condiciones deben cumplirse |
# | `or` | al menos una condición debe cumplirse |
# | `not` | niega una condición |

# %% [markdown]
# ## 5. Estructuras condicionales
#
# Las estructuras condicionales permiten ejecutar código dependiendo de una condición.
#
# La estructura básica es:
#
# ```python
# if condicion:
#     instrucciones
# elif otra_condicion:
#     instrucciones
# else:
#     instrucciones
# ```

# %% [markdown]
# ### Ejemplo aplicado: clasificación de consumo de corriente

# %% [markdown]
# ## 6. Ciclo `for`
#
# El ciclo `for` permite recorrer una secuencia de datos. Es muy útil cuando se tienen varias mediciones.

# %% [markdown]
# También se puede usar `range()` para repetir una acción un número determinado de veces.

# %% [markdown]
# ### Clasificación de varias mediciones usando `for`

# %% [markdown]
# ## 7. Ciclo `while`
#
# El ciclo `while` repite instrucciones mientras una condición sea verdadera.

# %% [markdown]
# ### Uso de `break` y `continue`
#
# - `break`: detiene el ciclo.
# - `continue`: salta a la siguiente iteración.

# %% [markdown]
# ## 8. Listas
#
# Una lista permite almacenar varios elementos en una sola variable.
# Las listas son ordenadas, modificables y permiten valores repetidos.

# %%
corrientes = [1.5, 1.8, 2.0, 2.2, 2.1]

print(corrientes)
print("Primera medición:", corrientes[0])
print("Última medición:", corrientes[-1])
print("Tres primeras mediciones:", corrientes[0:3])

# %% [markdown]
# ### Métodos comunes de listas

# %%
corrientes = [1.5, 1.8, 2.0]



print("Lista actualizada:", corrientes)


print("Después de eliminar 1.8:", corrientes)


print("Último valor eliminado:", ultimo)
print("Lista final:", corrientes)

# %% [markdown]
# ### Cálculos básicos con listas

# %%
print("Temperatura mínima:", min(temperaturas))
print("Temperatura máxima:", max(temperaturas))
print("Temperatura promedio:", promedio)

# %% [markdown]
# ## 9. Tuplas
#
# Una tupla es una colección ordenada e inmutable.
# Se usa cuando los datos no deberían cambiar, por ejemplo, coordenadas, rangos de operación o configuraciones fijas.

# %%
coordenada_robot = (2.5, 4.0)

print("Coordenada:", coordenada_robot)
print("x:", coordenada_robot[0])
print("y:", coordenada_robot[1])

# %% [markdown]
# ### Desempaquetado de tuplas

# %%
x, y = coordenada_robot

print("Posición x:", x)
print("Posición y:", y)

# %% [markdown]
# ## 10. Diccionarios
#
# Un diccionario almacena información en pares `clave: valor`.
# Es muy útil para representar registros estructurados.

# %%
motor = {
    "id": "M01",
    "tipo": "Motor DC",
    "voltaje_V": 12,
    "corriente_A": 1.8,
    "estado": "Activo"
}

print(motor)
print("Tipo:", motor["tipo"])
print("Estado:", motor["estado"])

# %% [markdown]
# ### Acceso, actualización y creación de claves

# %%
motor["temperatura_C"] = 42.5
motor["estado"] = "Precaución"

print(motor)
print("Potencia:", motor["voltaje_V"] * motor["corriente_A"], "W")

# %% [markdown]
# ### Uso de `.get()`
#
# El método `.get()` permite consultar una clave sin producir error si la clave no existe.

# %%
print(motor.get("ubicacion", "Ubicación no registrada"))

# %% [markdown]
# ### Lista de diccionarios
#
# En análisis de datos, muchas veces se tienen varios registros. Una forma básica de representarlos es una lista de diccionarios.

# %%
registros = [
    {"muestra": 1, "temperatura_C": 35.2, "corriente_A": 1.5},
    {"muestra": 2, "temperatura_C": 38.0, "corriente_A": 1.7},
    {"muestra": 3, "temperatura_C": 41.5, "corriente_A": 2.0},
]

for registro in registros:
    print(registro["muestra"], registro["temperatura_C"], registro["corriente_A"])

# %% [markdown]
# ## 11. Conjuntos
#
# Un conjunto o `set` almacena valores únicos.
# Es útil para eliminar duplicados o identificar categorías diferentes.

# %%
sensores = ["temperatura", "corriente", "vibracion", "temperatura", "corriente"]
sensores_unicos = set(sensores)

print("Sensores originales:", sensores)
print("Sensores únicos:", sensores_unicos)

# %% [markdown]
# ### Operaciones con conjuntos

# %%
sensores_equipo_A = {"temperatura", "corriente", "vibracion"}
sensores_equipo_B = {"temperatura", "presion", "flujo"}

print("Unión:", sensores_equipo_A | sensores_equipo_B)
print("Intersección:", sensores_equipo_A & sensores_equipo_B)
print("Solo en A:", sensores_equipo_A - sensores_equipo_B)
print("Diferencia simétrica:", sensores_equipo_A ^ sensores_equipo_B)

# %% [markdown]
# ## 12. Ejercicio: mini caso integrador
#
# Se tiene una lista de registros de medición de un motor.
# Cada registro contiene temperatura, corriente y velocidad.
# Se requiere clasificar el estado de cada medición.

# %%
mediciones_motor = [
    {"muestra": 1, "temperatura_C": 36, "corriente_A": 1.7, "rpm": 1200},
    {"muestra": 2, "temperatura_C": 42, "corriente_A": 2.1, "rpm": 1250},
    {"muestra": 3, "temperatura_C": 48, "corriente_A": 2.8, "rpm": 1300},
    {"muestra": 4, "temperatura_C": 55, "corriente_A": 3.4, "rpm": 1350},
]

for ...

mediciones_motor

# %% [markdown]
# Convertimos la lista de diccionarios en un `DataFrame` para verla como tabla.

# %%
import pandas as pd

df_motor = pd.DataFrame(mediciones_motor)
df_motor

# %% [markdown]
# ## 13. Preguntas de cierre
#
# Responda en una celda de texto:
#
# 1. ¿Cuál es la diferencia entre una lista y una tupla?
# 2. ¿Cuándo usaría un diccionario para representar datos?
# 3. ¿Por qué los conjuntos son útiles para identificar categorías?
# 4. ¿Qué estructura de datos usaría para representar varias mediciones de un sensor?
# 5. ¿Qué tema de Python considera que debe practicar más?
